# %%
def validar (x):
    paises= "colombia"
    if x in paises:
        print(f"Bogota")
    
    paises= "peru"
    if x in paises:
        print(f"Lima")

    paises= "venezuela"
    if x in paises:
        print(f"Caracas")

    paises= "uruguay"
    if x in paises:
        print(f"Montevideo")

    paises= "trinidad y tobago"
    if x in paises:
        print(f"Puerto España")

    paises= "surinam"
    if x in paises:
        print(f"Paramaribo")

    paises= "santa lucía"
    if x in paises:
        print(f"Castries")

    paises= "san vicente y las granadinas"
    if x in paises:
        print(f"Kingstown")

    paises= "san cristóbal y nieves"
    if x in paises:
        print(f"Basseterre")

    paises= "república dominicana"
    if x in paises:
        print(f"Santo Domingo")

    paises= "paraguay"
    if x in paises:
        print(f"Asunción")

    paises= "panamá"
    if x in paises:
        print(f"Panamá")

    paises= "nicaragua"
    if x in paises:
        print(f"Managua")

    paises= "méxico"
    if x in paises:
        print(f"Ciudad de Mexico")

    paises= "jamaica"
    if x in paises:
        print(f"Kingston")

    paises= "honduras"
    if x in paises:
        print(f"Tegucigalpa y Comayagüela")

    paises= "haití"
    if x in paises:
        print(f"Puerto Príncipe")

    paises= "guyana"
    if x in paises:
        print(f"Georgetown")

    paises= "guatemala"
    if x in paises:
        print(f"Ciudad de Guatemala")

    paises= "granada"
    if x in paises:
        print(f"Saint George")

    paises= "estados unidos"
    if x in paises:
        print(f"Washington D. C.")

    paises= "el salvador"
    if x in paises:
        print(f"San Salvador")

    paises= "ecuador"
    if x in paises:
        print(f"Quito")

    paises= "dominica"
    if x in paises:
        print(f"Roseau")

    paises= "cuba"
    if x in paises:
        print(f"La Habana")

    paises= "costa rica"
    if x in paises:
        print(f"La Habana")

    paises= "chile"
    if x in paises:
        print(f"Santiago de Chile")

    paises= "canadá"
    if x in paises:
        print(f"Ottawa")

    paises= "brasil"
    if x in paises:
        print(f"Brasilia")

    paises= "bolivia"
    if x in paises:
        print(f"Sucre")

    paises= "bolivia"
    if x in paises:
        print(f"Sucre")

    paises= "belice"
    if x in paises:
        print(f"Belmopán")

    paises= "barbados"
    if x in paises:
        print(f"Bridgetown")

    paises= "bahamas"
    if x in paises:
        print(f"Nasáu")



    paises= "Argentina"
    if x in paises:
        print(f"Buenos Aires")



    paises= "antigua y barbuda"
    if x in paises:
        print(f"Saint John's")

    




letra = input("Ingresa el pais de America: ")
validar(letra)
